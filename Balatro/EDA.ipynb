# %%
import json
import pandas as pd

# %%
with open("data/session_1755977553_1884_20250824_074508.json",'r') as file:
    test = json.load(file)

# %%
test['states'][100]
# Out:
# {'jokers': [{'ability': {'bonus': 0,
#     'x_mult': 1,
#     'hands_played_at_create': 2,
#     'h_size': 0,
#     'x_chips': 1,
#     'perma_h_mult': 0,
#     'mult': 0,
#     'perma_x_mult': 0,
#     'h_chips': 0,
#     'perma_h_dollars': 0,
#     'h_x_chips': 1,
#     'h_mult': 0,
#     'perma_h_x_mult': 0,
#     'effect': 'Tarot Buff',
#     'perma_mult': 0,
#     't_mult': 0,
#     'perma_h_chips': 0,
#     'h_dollars': 0,
#     'set': 'Joker',
#     'order': 142,
#     'perma_x_chips': 0,
#     'perma_p_dollars': 0,
#     'extra_value': 0,
#     'perma_h_x_chips': 0,
#     'perma_bonus': 0,
#     'p_dollars': 0,
#     'h_x_mult': 0,
#     'type': '',
#     't_chips': 0,
#     'name': 'Cartomancer',
#     'd_size': 0},
#    'x_mult': 0,
#    'label': 'Cartomancer',
#    'chips': 0,
#    'x_h_mult': 0,
#    'mult': 0},
#   {'ability': {'bonus': 0,
#     'x_mult': 1,
#     'couponed': True,
#     'hands_played_at_create': 10,
#     'h_size': 0,
#     'x_chips': 1,
# ...

# %%
states = pd.DataFrame(test['states'][100]['deck'])
actions = pd.DataFrame(test['actions'])

# %%
states['card_key'].value_counts()
# Out:
# card_key
# S_5    1
# S_J    1
# S_2    1
# S_K    1
# H_7    1
# D_3    1
# D_4    1
# H_T    1
# D_7    1
# S_T    1
# D_Q    1
# C_K    1
# D_T    1
# C_A    1
# H_Q    1
# D_8    1
# S_8    1
# D_2    1
# C_5    1
# C_6    1
# C_T    1
# D_5    1
# C_8    1
# D_J    1
# S_9    1
# C_J    1
# H_9    1
# C_9    1
# S_7    1
# H_3    1
# H_K    1
# D_A    1
# D_K    1
# H_2    1
# S_4    1
# C_3    1
# C_2    1
# C_4    1
# H_6    1
# S_3    1
# D_9    1
# Name: count, dtype: int64

# %%
actions
# Out:
#       timestamp                      gamestate_id  \
# 0    1755977558  1755977553_1884_GS498_1755977553
# 1    1755977564  1755977553_1884_GS499_1755977558
# 2    1755977569  1755977553_1884_GS500_1755977565
# 3    1755977576  1755977553_1884_GS501_1755977569
# 4    1755977585  1755977553_1884_GS502_1755977576
# ..          ...                               ...
# 115  1755978260  1755977553_1884_GS605_1755978255
# 116  1755978273  1755977553_1884_GS606_1755978260
# 117  1755978280  1755977553_1884_GS607_1755978273
# 118  1755978283  1755977553_1884_GS608_1755978280
# 119  1755978292  1755977553_1884_GS609_1755978283
#
#                                              card_info       session_id  \
# 0                                                   []  1755977553_1884
# 1    {'discarded_cards': [{'suit': 'Clubs', 'positi...  1755977553_1884
# 2    {'hand_played': {'level': 1, 'total_score': 16...  1755977553_1884
# ...
